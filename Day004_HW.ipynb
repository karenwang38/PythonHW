# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# #### Ans : 「r.text」把整個檔案內容當成一個字串讀出來，json.loads(r.text)把整的檔案內容分兩層，第一層用list分項目，第二層用dict去做每一個項目的分類。

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"11631860725","type":"PushEvent","actor":{"id":19503170,"login":"simoneluciano21","display_login":"simoneluciano21","gravatar_id":"","url":"https://api.github.com/users/simoneluciano21","avatar_url":"https://avatars.githubusercontent.com/u/19503170?"},"repo":{"id":215310811,"name":"simoneluciano21/LinearAlgebraicRepresentation.jl","url":"https://api.github.com/repos/simoneluciano21/LinearAlgebraicRepresentation.jl"},"payload":{"push_id":4693356331,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"0989916fd512c1988cc1648b543c524c7132aaf1","before":"851e36fbc6110d667caaf2fd903ec218d8915d6d","commits":[{"sha":"0989916fd512c1988cc1648b543c524c7132aaf1","author":{"email":"simone.luciano21@gmail.com","name":"SImone"},"message":"ii_threads","distinct":true,"url":"https://api.github.com/repos/simoneluciano21/LinearAlgebraicRepresentation.jl/commits/0989916fd512c1988cc1648b543c524c7132aaf1"}]},"public":true,"created_at":"2020-02-28T02:53:56Z"},{"id":"11631860723","type":"Fo
# ...

# %%
type(r.text)
# Out:
# str

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '11631860725',
#   'type': 'PushEvent',
#   'actor': {'id': 19503170,
#    'login': 'simoneluciano21',
#    'display_login': 'simoneluciano21',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/simoneluciano21',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19503170?'},
#   'repo': {'id': 215310811,
#    'name': 'simoneluciano21/LinearAlgebraicRepresentation.jl',
#    'url': 'https://api.github.com/repos/simoneluciano21/LinearAlgebraicRepresentation.jl'},
#   'payload': {'push_id': 4693356331,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0989916fd512c1988cc1648b543c524c7132aaf1',
#    'before': '851e36fbc6110d667caaf2fd903ec218d8915d6d',
#    'commits': [{'sha': '0989916fd512c1988cc1648b543c524c7132aaf1',
#      'author': {'email': 'simone.luciano21@gmail.com', 'name': 'SImone'},
#      'message': 'ii_threads',
#      'distinct': True,
# ...

# %%
type(json.loads(r.text))
# Out:
# list

# %%
json.loads(r.text)[1]
# Out:
# {'id': '11631860723',
#  'type': 'ForkEvent',
#  'actor': {'id': 20842481,
#   'login': 'ChanaLii',
#   'display_login': 'ChanaLii',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/ChanaLii',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/20842481?'},
#  'repo': {'id': 91865410,
#   'name': 'askme765cs/Wine-QQ-TIM',
#   'url': 'https://api.github.com/repos/askme765cs/Wine-QQ-TIM'},
#  'payload': {'forkee': {'id': 243665198,
#    'node_id': 'MDEwOlJlcG9zaXRvcnkyNDM2NjUxOTg=',
#    'name': 'Wine-QQ-TIM',
#    'full_name': 'ChanaLii/Wine-QQ-TIM',
#    'private': False,
#    'owner': {'login': 'ChanaLii',
#     'id': 20842481,
#     'node_id': 'MDQ6VXNlcjIwODQyNDgx',
#     'avatar_url': 'https://avatars0.githubusercontent.com/u/20842481?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/ChanaLii',
#     'html_url': 'https://github.com/ChanaLii',
#     'followers_url': 'https://api.github.com/users/ChanaLii/followers',
# ...

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
url = 'https://cat-fact.herokuapp.com/facts'
r = requests.get(url)
json.loads(r.text)
# Out:
# {'all': [{'_id': '58e008ad0aac31001185ed0c',
#    'text': "The frequency of a domestic cat's purr is the same at which muscles and bones repair themselves.",
#    'type': 'cat',
#    'user': {'_id': '58e007480aac31001185ecef',
#     'name': {'first': 'Kasimir', 'last': 'Schulz'}},
#    'upvotes': 9,
#    'userUpvoted': None},
#   {'_id': '5b1b411d841d9700146158d9',
#    'text': 'The Egyptian Mau’s name is derived from the Middle Egyptian word mjw, which means cat. But contrary to its name, it’s unclear whether the modern Egyptian Mau actually originated in Egypt.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
#     'name': {'first': 'Alex', 'last': 'Wohlbruck'}},
#    'upvotes': 6,
#    'userUpvoted': None},
#   {'_id': '5b4912c60508220014ccfe99',
#    'text': 'Cats aren’t the only animals that purr — squirrels, lemurs, elephants, and even gorillas purr too.',
#    'type': 'cat',
#    'user': {'_id': '5a9ac18c7478810ea6c06381',
# ...

# %%
url = 'https://cloud.culture.tw/frontsite/trans/SearchShowAction.do?method=doFindTypeJOpenApi&category=4'
r = requests.get(url)
json.loads(r.text)
# Out:
# {'openapi': '3.0.1',
#  'info': {'title': '親子活動',
#   'description': '親子類型的藝文資訊JSON格式',
#   'termsOfService': 'https://opendata.culture.tw/cms/1958862',
#   'contact': {'name': '陳小姐', 'email': 'grace@moc.gov.tw'},
#   'license': {'name': '政府資料開放授權條款-第1版', 'url': 'https://data.gov.tw/license'},
#   'version': '1.4'},
#  'servers': [{'url': 'https://cloud.culture.tw', 'description': '文化部活動網站'}],
#  'paths': {'/frontsite/trans/SearchShowAction.do': {'get': {'operationId': 'activityGet',
#     'parameters': [{'name': 'method',
#       'in': 'query',
#       'required': True,
#       'schema': {'type': 'string',
#        'default': 'doFindTypeJ',
#        'enum': ['doFindTypeJ']}},
#      {'name': 'category',
#       'in': 'query',
#       'required': True,
#       'schema': {'type': 'string', 'default': '4', 'enum': ['4']}}],
#     'responses': {'200': {'description': '成功',
#       'content': {'application/json': {'schema': {'type': 'array',
# ...

# %%
# 文化資料開放
# 親子類型的藝文資訊JSON格式
url = 'https://cloud.culture.tw/frontsite/trans/SearchShowAction.do?method=doFindTypeJ&category=4'
r = requests.get(url)
json.loads(r.text)
# Out:
# [{'version': '1.4',
#   'UID': '5bd72a07d083a325986720dc',
#   'title': '台北兒童象棋研習營',
#   'category': '4',
#   'showInfo': [{'time': '2019/10/23 00:00:00',
#     'location': '臺北市大安區新生南路一段161巷35-1號2樓',
#     'locationName': '名揚象棋會館',
#     'onSales': 'Y',
#     'price': '請電洽',
#     'latitude': None,
#     'longitude': None,
#     'endTime': '2020/06/28 23:59:59'}],
#   'showUnit': '',
#   'discountInfo': '',
#   'descriptionFilterHtml': '活動簡章：台北兒童象棋研習營(依程度安排)參加對象：對象棋有興趣之兒童6-12歲研習梯次：請參照粉絲團(名揚象棋粉絲團)或名揚象棋網站\xa0https://janny0685.wixsite.com/mychess/about1-czcj研習地點：台北市大安區新生南路一段161巷35-1號2樓(捷運大安森林公園站6號出口)報名方式：預約報名制，請電洽2706-1211陳老師活動介紹：讓兒童了解象棋藝術之美，學會正確的象棋方法與棋品禮貌，有提供象棋升級升段的管道。依程度分為入門研習、初階研習、高階研習、段位研習。\xa0歡迎有興趣的同學預約報名參加。',
#   'imageUrl': '',
#   'masterUnit': [],
#   'subUnit': [],
#   'supportUnit': [],
#   'otherUnit': [],
#   'webSales': 'https://janny0685.wixsite.com/mychess/about1-czcj',
#   'sourceWebPromote': '',
#   'comment': '',
#   'editModifyDate': '',
# ...

# %%
len(json.loads(r.text))
# Out:
# 56

# %%
json.loads(r.text)[0]
# Out:
# {'version': '1.4',
#  'UID': '5bd72a07d083a325986720dc',
#  'title': '台北兒童象棋研習營',
#  'category': '4',
#  'showInfo': [{'time': '2019/10/23 00:00:00',
#    'location': '臺北市大安區新生南路一段161巷35-1號2樓',
#    'locationName': '名揚象棋會館',
#    'onSales': 'Y',
#    'price': '請電洽',
#    'latitude': None,
#    'longitude': None,
#    'endTime': '2020/06/28 23:59:59'}],
#  'showUnit': '',
#  'discountInfo': '',
#  'descriptionFilterHtml': '活動簡章：台北兒童象棋研習營(依程度安排)參加對象：對象棋有興趣之兒童6-12歲研習梯次：請參照粉絲團(名揚象棋粉絲團)或名揚象棋網站\xa0https://janny0685.wixsite.com/mychess/about1-czcj研習地點：台北市大安區新生南路一段161巷35-1號2樓(捷運大安森林公園站6號出口)報名方式：預約報名制，請電洽2706-1211陳老師活動介紹：讓兒童了解象棋藝術之美，學會正確的象棋方法與棋品禮貌，有提供象棋升級升段的管道。依程度分為入門研習、初階研習、高階研習、段位研習。\xa0歡迎有興趣的同學預約報名參加。',
#  'imageUrl': '',
#  'masterUnit': [],
#  'subUnit': [],
#  'supportUnit': [],
#  'otherUnit': [],
#  'webSales': 'https://janny0685.wixsite.com/mychess/about1-czcj',
#  'sourceWebPromote': '',
#  'comment': '',
#  'editModifyDate': '',
#  'sourceWebName': '臺北市政府文化局文化快遞網站',
# ...

# %%
json.loads(r.text)[1]['title']
# Out:
# '古蹟漫步—臺北琴道館、臺北書畫院導覽'

# %%
json.loads(r.text)[1]['showInfo']
# Out:
# [{'time': '2019/04/06 00:00:00',
#   'location': '臺北市中正區齊東街53巷11號',
#   'locationName': '臺北琴道舘台北書畫院',
#   'onSales': 'N',
#   'price': '',
#   'latitude': None,
#   'longitude': None,
#   'endTime': '2020/12/26 23:59:59'}]

# %%
for i in range(len(json.loads(r.text))):
    print(json.loads(r.text)[i]['title'])
    print(json.loads(r.text)[i]['showInfo'])
    print('=========\n')
# Out:
# 台北兒童象棋研習營
# [{'time': '2019/10/23 00:00:00', 'location': '臺北市大安區新生南路一段161巷35-1號2樓', 'locationName': '名揚象棋會館', 'onSales': 'Y', 'price': '請電洽', 'latitude': None, 'longitude': None, 'endTime': '2020/06/28 23:59:59'}]
# ...
#
# 古蹟漫步—臺北琴道館、臺北書畫院導覽
# [{'time': '2019/04/06 00:00:00', 'location': '臺北市中正區齊東街53巷11號', 'locationName': '臺北琴道舘台北書畫院', 'onSales': 'N', 'price': '', 'latitude': None, 'longitude': None, 'endTime': '2020/12/26 23:59:59'}]
# ...
#
# 《公主百分百》舞蹈音樂劇
# ...
