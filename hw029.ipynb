# %%
# !cd Users/karenwang/Desktop/Program/Python/SpiderCourse/PythonHW/Day029_Scrapy_PTT/myproject/
# !python3 main.py
# Out:
# /bin/sh: line 0: cd: Users/karenwang/Desktop/Program/Python/SpiderCourse/PythonHW/Day029_Scrapy_PTT/myproject/: No such file or directory
# 2020-03-28 16:19:38 [scrapy.utils.log] INFO: Scrapy 2.0.1 started (bot: myproject)
# 2020-03-28 16:19:38 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 18.9.0, Python 3.7.0 (default, Oct  2 2018, 09:20:07) - [Clang 10.0.0 (clang-1000.11.45.2)], pyOpenSSL 17.0.0 (OpenSSL 1.1.0j  20 Nov 2018), cryptography 2.4.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2020-03-28 16:19:38 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-03-28 16:19:38 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'myproject',
#  'NEWSPIDER_MODULE': 'myproject.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['myproject.spiders']}
# 2020-03-28 16:19:38 [scrapy.extensions.telnet] INFO: Telnet Password: 596cf3524502b95c
# ...

# %%
pwd
# Out:
# '/Users/karenwang/Desktop/Program/Python/SpiderCourse/PythonHW/hw029'

# %%
# !cd /Users/karenwang/Desktop/Program/Python/SpiderCourse/PythonHW/hw029
# !python3 main.py
# Out:
# 2020-03-28 16:27:28 [scrapy.utils.log] INFO: Scrapy 2.0.1 started (bot: hw026)
# 2020-03-28 16:27:28 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 18.9.0, Python 3.7.0 (default, Oct  2 2018, 09:20:07) - [Clang 10.0.0 (clang-1000.11.45.2)], pyOpenSSL 17.0.0 (OpenSSL 1.1.0j  20 Nov 2018), cryptography 2.4.2, Platform Darwin-17.7.0-x86_64-i386-64bit
# 2020-03-28 16:27:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-03-28 16:27:28 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'hw026',
#  'NEWSPIDER_MODULE': 'hw026.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['hw026.spiders']}
# 2020-03-28 16:27:28 [scrapy.extensions.telnet] INFO: Telnet Password: cb9865073678c05e
# 2020-03-28 16:27:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
# ...
