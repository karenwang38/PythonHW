# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
import requests
from bs4 import BeautifulSoup
import random


url = 'https://free-proxy-list.net/'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')



proxy_ips = []

ip_table = soup.find(class_='table table-striped table-bordered')
for i in ip_table.find_all('tr'):
    if i.td == None:
        continue
    else:
#         print(i.td.text)
        proxy_ips.append(i.td.text)
proxy_ips
# Out:
# ['119.81.199.86',
#  '5.252.161.48',
#  '161.202.226.195',
#  '165.227.215.62',
#  '138.68.24.145',
#  '31.220.50.132',
#  '187.16.43.242',
#  '190.103.178.14',
#  '177.66.255.141',
#  '82.99.232.18',
#  '95.217.176.214',
#  '31.146.31.182',
#  '90.189.110.170',
#  '66.42.42.89',
#  '81.91.144.53',
#  '119.81.71.27',
#  '79.151.154.27',
#  '203.77.252.250',
#  '201.174.132.217',
#  '159.89.82.38',
#  '139.59.59.63',
#  '198.199.120.102',
#  '45.55.27.161',
#  '119.81.199.82',
#  '92.222.180.156',
#  '176.9.75.42',
#  '103.240.161.109',
#  '186.216.81.21',
#  '179.184.230.194',
#  '103.254.94.17',
#  '115.249.2.192',
#  '88.99.10.253',
#  '178.217.216.184',
#  '195.69.221.198',
#  '46.28.229.78',
#  '88.255.63.53',
#  '103.28.226.125',
#  '46.191.226.105',
#  '204.15.243.233',
#  '94.130.179.24',
#  '103.105.77.15',
#  '117.54.13.174',
#  '88.99.10.251',
#  '202.166.220.150',
#  '78.46.81.7',
#  '188.40.183.185',
#  '178.32.214.145',
#  '188.0.138.147',
#  '192.241.245.207',
#  '169.57.157.146',
#  '188.226.141.211',
#  '161.202.226.194',
#  '191.96.42.80',
#  '165.227.215.71',
#  '46.151.108.6',
#  '188.226.141.127',
#  '119.81.199.84',
#  '119.28.133.75',
#  '138.197.169.148',
#  '45.161.202.2',
#  '52.179.231.206',
#  '88.204.193.69',
#  '216.98.9.150',
#  '45.55.9.218',
#  '200.222.16.238',
#  '144.217.163.138',
#  '139.59.169.246',
#  '139.59.99.119',
#  '178.62.193.19',
#  '88.198.24.108',
#  '150.109.32.166',
#  '119.81.199.87',
#  '139.59.109.156',
#  '88.99.10.250',
#  '200.89.178.196',
#  '138.197.222.35',
#  '207.154.231.213',
#  '169.57.157.148',
#  '88.198.50.103',
#  '207.154.231.211',
#  '159.65.151.96',
#  '67.205.146.29',
#  '119.81.199.80',
#  '192.41.19.53',
#  '119.81.199.85',
#  '159.138.35.74',
#  '188.166.83.34',
#  '128.199.246.10',
#  '203.202.245.62',
#  '139.59.101.223',
#  '188.166.83.20',
#  '207.154.231.212',
#  '139.59.99.63',
#  '63.82.52.254',
#  '151.232.72.13',
#  '128.199.245.99',
#  '186.189.235.93',
#  '104.248.35.115',
#  '119.81.199.83',
#  '80.187.140.26',
#  '125.25.40.37',
#  '88.204.193.66',
#  '191.241.166.251',
#  '118.200.73.124',
#  '60.251.33.224',
#  '88.204.193.67',
#  '95.179.197.59',
#  '45.144.240.56',
#  '36.89.192.119',
#  '191.252.100.178',
#  '62.171.161.146',
#  '128.199.245.98',
#  '131.161.47.34',
#  '198.50.152.64',
#  '103.216.82.206',
#  '144.76.214.154',
#  '117.242.147.181',
#  '49.248.154.237',
#  '206.189.36.13',
#  '185.63.46.205',
#  '115.124.78.142',
#  '103.216.82.190',
#  '1.20.97.96',
#  '124.41.240.43',
#  '82.200.233.4',
#  '176.113.126.127',
#  '125.99.58.110',
#  '176.56.107.72',
#  '124.41.211.153',
#  '41.164.247.186',
#  '77.83.175.235',
#  '182.52.238.44',
#  '45.64.179.82',
#  '50.194.62.37',
#  '187.188.175.251',
#  '93.78.238.94',
#  '213.32.252.120',
#  '171.103.139.126',
#  '5.63.165.178',
#  '117.6.161.118',
#  '118.99.118.33',
#  '27.68.135.14',
#  '200.25.254.193',
#  '134.122.29.170',
#  '189.57.62.146',
#  '51.83.66.231',
#  '173.212.202.65',
#  '169.204.212.254',
#  '5.59.141.152',
#  '5.15.30.5',
#  '187.87.38.28',
#  '180.241.147.153',
#  '144.76.214.155',
#  '144.76.214.152',
#  '146.88.23.225',
#  '52.183.135.91',
#  '94.182.229.47',
#  '181.30.28.54',
#  '125.209.66.202',
#  '144.76.214.159',
#  '190.11.15.14',
#  '200.37.209.195',
#  '200.73.128.5',
#  '201.64.22.51',
#  '200.41.94.105',
#  '161.156.69.189',
#  '177.125.20.35',
#  '96.9.80.62',
#  '132.255.89.195',
#  '94.228.85.166',
#  '171.100.102.154',
#  '41.254.46.102',
#  '18.194.147.163',
#  '144.76.214.153',
#  '103.216.82.44',
#  '188.40.183.189',
#  '179.108.169.71',
#  '196.216.13.59',
#  '192.199.53.131',
#  '178.213.0.207',
#  '195.230.115.115',
#  '143.255.40.106',
#  '45.123.26.146',
#  '103.78.75.165',
#  '186.159.2.241',
#  '190.6.200.158',
#  '1.20.101.62',
#  '23.91.219.238',
#  '38.126.254.114',
#  '51.77.149.1',
#  '187.60.34.234',
#  '103.213.116.195',
#  '5.141.10.126',
#  '91.122.46.45',
#  '187.111.176.193',
#  '185.173.245.127',
#  '194.158.84.204',
#  '195.182.22.178',
#  '201.20.98.22',
#  '132.255.92.34',
#  '45.132.105.194',
#  '79.137.254.51',
#  '103.37.81.92',
#  '37.135.50.254',
#  '194.143.151.96',
#  '144.91.116.171',
#  '200.69.81.198',
#  '117.102.104.131',
#  '102.164.222.60',
#  '1.20.97.4',
#  '217.219.247.208',
#  '202.61.49.52',
#  '213.6.227.38',
#  '45.64.99.25',
#  '95.80.252.189',
#  '180.179.98.22',
#  '77.94.107.148',
#  '170.247.152.132',
#  '182.16.171.65',
#  '118.97.53.99',
#  '46.241.120.230',
#  '110.74.198.146',
#  '91.187.113.205',
#  '155.0.181.254',
#  '103.216.82.153',
#  '191.37.183.209',
#  '91.135.194.22',
#  '82.140.113.243',
#  '102.164.217.110',
#  '197.216.2.14',
#  '185.204.208.78',
#  '128.199.217.244',
#  '103.236.161.254',
#  '176.9.46.130',
#  '200.89.159.153',
#  '75.80.242.9',
#  '170.254.176.113',
#  '63.232.67.5',
#  '202.179.7.182',
#  '163.172.135.104',
#  '213.58.202.70',
#  '112.78.187.186',
#  '94.141.244.39',
#  '131.196.141.80',
#  '193.117.138.126',
#  '186.211.106.227',
#  '119.63.132.90',
#  '1.20.103.196',
#  '190.90.63.137',
#  '191.98.198.42',
#  '94.230.156.143',
#  '110.74.199.68',
#  '125.25.80.39',
#  '147.135.244.36',
#  '200.199.114.226',
#  '209.97.159.125',
#  '108.7.183.15',
#  '190.103.178.13',
#  '118.69.50.154',
#  '91.225.226.39',
#  '60.251.33.225',
#  '113.53.230.167',
#  '82.119.170.106',
#  '47.75.90.57',
#  '178.151.156.112',
#  '80.48.119.28',
#  '94.182.229.167',
#  '190.216.147.70',
#  '154.0.14.113',
#  '54.246.192.128',
#  '186.195.82.9',
#  '223.27.196.18',
#  '206.125.41.135',
#  '187.1.32.34',
#  '103.76.175.88',
#  '45.76.39.26',
#  '27.147.209.215',
#  '169.255.234.166',
#  '160.20.147.117',
#  '18.163.28.22',
#  '198.236.196.5',
#  '194.44.110.204',
#  '188.32.137.250',
#  '190.103.178.15',
#  '150.129.171.123',
#  '212.220.216.70',
#  '91.67.240.32',
#  '176.209.73.168',
#  '89.175.188.58',
#  '62.99.178.46',
#  '194.167.44.91',
#  '46.98.56.219',
#  '200.73.129.85',
#  '181.118.167.104',
#  '210.210.128.166',
#  '46.174.234.189',
#  '5.189.133.231',
#  '88.135.210.179',
#  '204.15.243.234',
#  '41.203.240.50']

# %%
for i in range(len(proxy_ips)):
    ip = random.choice(proxy_ips)
    print('Use', ip)
    try:
        resp = requests.get('http://ip.filefab.com/index.php',
                        proxies={'http': ip, 'https': ip}, timeout=10)
        soup = BeautifulSoup(resp.text, 'html5lib')
        print(soup.find('h1', id='ipd').text.strip())
    except:
        print('Fail')
# Out:
# Use 103.216.82.206
# Fail
# Use 181.118.167.104
# Fail
# Use 182.52.238.44
# Fail
# Use 185.63.46.205
# Fail
# Use 82.119.170.106
# Fail
# Use 146.88.23.225
# Fail
# Use 187.60.34.234
# Fail
# Use 154.0.14.113
# Fail
# Use 119.81.199.86
# Fail
# Use 79.137.254.51
# Fail
# Use 66.42.42.89
# Fail
# Use 108.7.183.15
# Fail
# Use 104.248.35.115
# Fail
# Use 223.27.196.18
# Fail
# Use 161.202.226.195
# Fail
# Use 103.76.175.88
# Fail
# Use 103.216.82.44
# Fail
# Use 223.27.196.18
# Fail
# Use 207.154.231.213
# Fail
# Use 198.236.196.5
# Fail
# Use 88.99.10.250
# Fail
# Use 144.76.214.159
# Fail
# Use 169.255.234.166
# Fail
# Use 119.63.132.90
# Fail
# Use 88.255.63.53
# Fail
# Use 181.30.28.54
# Fail
# Use 110.74.199.68
# Fail
# Use 62.171.161.146
# Fail
# Use 207.154.231.211
# Fail
# Use 50.194.62.37
# Fail
# Use 171.100.102.154
# Fail
# Use 37.135.50.254
# Fail
# Use 1.20.97.96
# Fail
# Use 195.182.22.178
# Fail
# Use 45.55.9.218
# Fail
# Use 103.28.226.125
# Fail
# Use 165.227.215.62
# Fail
# Use 169.57.157.148
# Fail
# Use 124.41.211.153
# Fail
# Use 118.69.50.154
# Your IP address: 210.245.110.254
# Use 191.37.183.209
# Fail
# Use 195.230.115.115
