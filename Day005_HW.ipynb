# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# Ans: 30筆。
# 欄位['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar']
import requests
import json

url = 'https://www.dcard.tw/_api/forums/pet/posts?popular=true'
r = requests.get(url)
response = r.text

data = json.loads(response)
data
# Out:
# [{'id': 233147249,
#   'title': '有人有看過這麼有喜感的貓嗎',
#   'excerpt': '我家的貓天生帶有喜感，有些照片都可以做成貼圖來賣了，像極了清末在鴉片館的癮君子，又像是坦腹東床的王羲之 再躺也沒有人來相親啦，這三張拉近一看，你是在公三小 我的罐罐你拿去吃掉了？笑死人 聽你在歐北共，',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T00:41:45.740Z',
#   'updatedAt': '2020-02-27T02:12:02.293Z',
#   'commentCount': 89,
#   'likeCount': 1996,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '米克斯', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '國立政治大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6be5d281-2419-4f71-aa52-2f7710ca8392',
#     'url': 'https://i.imgur.com/xeJu68Il.jpg',
#     'normalizedUrl': 'https://i.imgur.com/xeJu68Il.jpg',
#     'thumbnail': 'https://i.imgur.com/xeJu68Il.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '6be5d281-2419-4f71-aa52-2f7710ca8392',
#     'url': 'https://i.imgur.com/xeJu68I.jpg',
#     'normalizedUrl': 'https://imgur.com/xeJu68I',
#     'thumbnail': 'https://i.imgur.com/xeJu68Il.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '3a84f595-94f9-41ba-8f71-a7e2421bf1a5',
#     'url': 'https://i.imgur.com/9wU5tWX.jpg',
#     'normalizedUrl': 'https://imgur.com/9wU5tWX',
#     'thumbnail': 'https://i.imgur.com/9wU5tWXl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': 'cb349ee1-36ae-493d-81ec-908fd648c570',
#     'url': 'https://i.imgur.com/8zf68zP.jpg',
#     'normalizedUrl': 'https://imgur.com/8zf68zP',
#     'thumbnail': 'https://i.imgur.com/8zf68zPl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '9e44d6f7-04d7-41c5-9e8f-7451c436f14e',
#     'url': 'https://i.imgur.com/D0KSJGO.jpg',
#     'normalizedUrl': 'https://imgur.com/D0KSJGO',
#     'thumbnail': 'https://i.imgur.com/D0KSJGOl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '9f9d49a4-f2be-4085-ac7a-c0ec6efa480c',
#     'url': 'https://i.imgur.com/MgOqlM5.jpg',
#     'normalizedUrl': 'https://imgur.com/MgOqlM5',
#     'thumbnail': 'https://i.imgur.com/MgOqlM5l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '5cd94ceb-5214-44bf-8e1a-5950c55ae7c8',
#     'url': 'https://i.imgur.com/kd73x0v.jpg',
#     'normalizedUrl': 'https://imgur.com/kd73x0v',
#     'thumbnail': 'https://i.imgur.com/kd73x0vl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': '319e31d0-8369-44fd-8dcf-c14c04a25fe1',
#     'url': 'https://i.imgur.com/RM0fag4.jpg',
#     'normalizedUrl': 'https://imgur.com/RM0fag4',
#     'thumbnail': 'https://i.imgur.com/RM0fag4l.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'},
#    {'id': 'a396f71c-4de9-4762-83c9-cfb576147bbd',
#     'url': 'https://i.imgur.com/Jj3IL0R.jpg',
#     'normalizedUrl': 'https://imgur.com/Jj3IL0R',
#     'thumbnail': 'https://i.imgur.com/Jj3IL0Rl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T00:41:45.740Z',
#     'updatedAt': '2020-02-27T02:12:02.293Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1872},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 124}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/xeJu68I.jpg'},
#    {'url': 'https://i.imgur.com/9wU5tWX.jpg'},
#    {'url': 'https://i.imgur.com/8zf68zP.jpg'},
#    {'url': 'https://i.imgur.com/D0KSJGO.jpg'},
#    {'url': 'https://i.imgur.com/MgOqlM5.jpg'},
#    {'url': 'https://i.imgur.com/kd73x0v.jpg'},
#    {'url': 'https://i.imgur.com/RM0fag4.jpg'},
#    {'url': 'https://i.imgur.com/Jj3IL0R.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233147080,
#   'title': '小蝦蝦不知道可不可以上熱門🥺',
#   'excerpt': '寵物板上很少看到玩水族的🥺有沒有人覺得蝦蝦超級療癒的！一直在黑土上找食物超可愛️，———————————————————，歡迎來到蝦蝦の世界🦐，紅/黑花虎基因蝦🤪，這缸裡面最美的黑花虎，雪花飼料',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-26T22:13:53.583Z',
#   'updatedAt': '2020-02-26T22:48:37.580Z',
#   'commentCount': 47,
#   'likeCount': 465,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '魚', '蝦', '魚缸', '蝦缸'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '南開科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '6250baef-160c-4689-915f-20331edefd09',
#     'url': 'https://megapx-assets.dcard.tw/images/94baa08c-fe12-408e-91c7-b18a9fff641f/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/94baa08c-fe12-408e-91c7-b18a9fff641f/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/94baa08c-fe12-408e-91c7-b18a9fff641f/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:13:53.583Z',
#     'updatedAt': '2020-02-26T22:48:37.580Z',
#     'width': 640,
#     'height': 360},
#    {'id': '6250baef-160c-4689-915f-20331edefd09',
#     'url': 'https://megapx-assets.dcard.tw/images/94baa08c-fe12-408e-91c7-b18a9fff641f/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/94baa08c-fe12-408e-91c7-b18a9fff641f',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/94baa08c-fe12-408e-91c7-b18a9fff641f/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:13:53.583Z',
#     'updatedAt': '2020-02-26T22:48:37.580Z',
#     'width': 2000,
#     'height': 1125},
#    {'id': '6d938e52-0a44-4979-b443-44d88df8e044',
#     'url': 'https://megapx-assets.dcard.tw/images/d6157460-c10a-4a2b-80cf-f84ea6fd87d0/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/d6157460-c10a-4a2b-80cf-f84ea6fd87d0',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/d6157460-c10a-4a2b-80cf-f84ea6fd87d0/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:13:53.583Z',
#     'updatedAt': '2020-02-26T22:48:37.580Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '4e0c4387-29db-47b5-a1fe-8446a8e38270',
#     'url': 'https://megapx-assets.dcard.tw/images/1c575a86-18d0-4ed0-965d-d251b79da5fb/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/1c575a86-18d0-4ed0-965d-d251b79da5fb',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/1c575a86-18d0-4ed0-965d-d251b79da5fb/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:13:53.583Z',
#     'updatedAt': '2020-02-26T22:48:37.580Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 
學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'b64c148c-d331-4d02-82b6-3e4d85ec51e8',
#     'url': 'https://imgur.dcard.tw/RnBQko5.jpg',
#     'normalizedUrl': 'https://imgur.dcard.tw/RnBQko5.jpg',
#     'thumbnail': 'https://imgur.dcard.tw/RnBQko5.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-02-27T08:00:49.162Z',
#     'updatedAt': '2020-02-27T08:00:49.162Z'},
#    {'id': 'b64c148c-d331-4d02-82b6-3e4d85ec51e8',
#     'url': 'https://imgur.dcard.tw/RnBQko5.jpg',
#     'normalizedUrl': '',
#     'thumbnail': 'https://imgur.dcard.tw/RnBQko5.jpg',
#     'type': 'image/jpeg',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-02-27T08:00:49.162Z',
#     'updatedAt': '2020-02-27T08:00:49.162Z'},
#    {'id': '030f61f6-e325-484b-abea-554ebcb07141',
#     'url': 'https://imgur.dcard.tw/vumYAp2.jpg',
#     'normalizedUrl': '',
#     'thumbnail': 'https://imgur.dcard.tw/vumYAp2.jpg',
#     'type': 'image/jpeg',
#     'tags': ['ANNOTATED_FAILED'],
#     'createdAt': '2020-02-27T08:00:49.162Z',
#     'updatedAt': '2020-02-27T08:00:49.162Z'},
#    {'id': '0435f775-f159-47ed-ba7a-c8e3eb4b056a',
#     'url': 'https://imgur.dcard.tw/VIyJRzb.jpg',
#     'normalizedUrl': '',
#     'thumbnail': 'https://imgur.dcard.tw/VIyJRzb.jpg',
#     'type': 'image/jpeg',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T08:00:49.162Z',
#     'updatedAt': '2020-02-27T08:00:49.162Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 111},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'http://i.imgur.com/RnBQko5.jpg'},
#    {'url': 'http://i.imgur.com/vumYAp2.jpg'},
#    {'url': 'http://i.imgur.com/VIyJRzb.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233147309,
#   'title': '不喜歡洗澡的狗',
#   'excerpt': '跟我家狗狗說洗澡之後，他用這樣無辜的眼神看著我（好可愛），因為他看起來真的很不想洗，（在同個地方坐了十幾分鐘也不動🤣），所以我就開始玩特效，（前幾天才發現有貓狗可以用的特效欸欸好酷XD），然後就有了',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T01:06:35.270Z',
#   'updatedAt': '2020-02-27T01:11:12.155Z',
#   'commentCount': 9,
#   'likeCount': 55,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['狗', '寵物', '可愛', '米克斯', '洗澡'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '酷斯拉 coolsila',
#   'department': 'coolsila',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '1ba13cc3-d7b4-47f0-924a-87e2f9a85b59',
#     'url': 'https://i.imgur.com/ArzYi6al.jpg',
#     'normalizedUrl': 'https://i.imgur.com/ArzYi6al.jpg',
#     'thumbnail': 'https://i.imgur.com/ArzYi6al.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'},
#    {'id': '1ba13cc3-d7b4-47f0-924a-87e2f9a85b59',
#     'url': 'http://i.imgur.com/ArzYi6a.jpg',
#     'normalizedUrl': 'https://imgur.com/ArzYi6a',
#     'thumbnail': 'https://i.imgur.com/ArzYi6al.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'},
#    {'id': '386fe537-8898-47ce-aa0e-47fc057b1ad7',
#     'url': 'http://i.imgur.com/wYLpiVH.jpg',
#     'normalizedUrl': 'https://imgur.com/wYLpiVH',
#     'thumbnail': 'https://i.imgur.com/wYLpiVHl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'},
#    {'id': '84353637-b277-4540-8133-c1e2fee7bbe8',
#     'url': 'http://i.imgur.com/lRTCXpG.jpg',
#     'normalizedUrl': 'https://imgur.com/lRTCXpG',
#     'thumbnail': 'https://i.imgur.com/lRTCXpGl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'},
#    {'id': '950e9089-219e-4f95-99ba-2ee8fd85b9f4',
#     'url': 'http://i.imgur.com/Pn99ZZo.jpg',
#     'normalizedUrl': 'https://imgur.com/Pn99ZZo',
#     'thumbnail': 'https://i.imgur.com/Pn99ZZol.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'},
#    {'id': '3f781da1-60b4-43dd-ba55-1cbafea1e238',
#     'url': 'http://i.imgur.com/CRpszcz.jpg',
#     'normalizedUrl': 'https://imgur.com/CRpszcz',
#     'thumbnail': 'https://i.imgur.com/CRpszczl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:11:12.155Z',
#     'updatedAt': '2020-02-27T01:11:12.155Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 53},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'http://i.imgur.com/ArzYi6a.jpg'},
#    {'url': 'http://i.imgur.com/wYLpiVH.jpg'},
#    {'url': 'http://i.imgur.com/lRTCXpG.jpg'},
#    {'url': 'http://i.imgur.com/Pn99ZZo.jpg'},
#    {'url': 'http://i.imgur.com/CRpszcz.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233151163,
#   'title': '拍屁屁奴隸的心聲',
#   'excerpt': '家裡有一隻胖貓貓，無時無刻都想被拍屁屁，可是⋯，我手很酸怎麼辦！，你看！他都這樣屁屁翹超高！，屁屁附近的毛都拍扁了～～可是她又很可愛！，真的是內心與手的拉扯啊啊啊啊，能不能發明自動拍屁屁機器，大家也有',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T13:38:01.565Z',
#   'updatedAt': '2020-02-27T13:38:35.658Z',
#   'commentCount': 5,
#   'likeCount': 34,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '東吳大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'bd7fda0c-3a64-4f34-89e6-c9d30a6296a8',
#     'url': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T13:38:01.565Z',
#     'updatedAt': '2020-02-27T13:38:35.658Z',
#     'width': 640,
#     'height': 480},
#    {'id': 'bd7fda0c-3a64-4f34-89e6-c9d30a6296a8',
#     'url': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T13:38:01.565Z',
#     'updatedAt': '2020-02-27T13:38:35.658Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'b7965c16-77c7-416b-9352-506de15b508f',
#     'url': 'https://megapx-assets.dcard.tw/images/3a62f116-2083-4184-baca-140f891e7297/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/3a62f116-2083-4184-baca-140f891e7297',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/3a62f116-2083-4184-baca-140f891e7297/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T13:38:01.565Z',
#     'updatedAt': '2020-02-27T13:38:35.658Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': 'd40cec30-0054-4909-bf1a-79ccbcff55e9',
#     'url': 'https://megapx-assets.dcard.tw/images/aabf6567-beb9-413c-a927-51e0bdaae918/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/aabf6567-beb9-413c-a927-51e0bdaae918',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/aabf6567-beb9-413c-a927-51e0bdaae918/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T13:38:01.565Z',
#     'updatedAt': '2020-02-27T13:38:35.658Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '2ac4049f-2d83-49c7-bb97-0715e90dbccb',
#     'url': 'https://megapx-assets.dcard.tw/images/2b2a4114-95d8-4e6a-b91c-ae9e82df4fae/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/2b2a4114-95d8-4e6a-b91c-ae9e82df4fae',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/2b2a4114-95d8-4e6a-b91c-ae9e82df4fae/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T13:38:01.565Z',
#     'updatedAt': '2020-02-27T13:38:35.658Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 32},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/bc8ad187-fbf6-4b4c-9846-e44b760bcd6d/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/3a62f116-2083-4184-baca-140f891e7297/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/aabf6567-beb9-413c-a927-51e0bdaae918/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/2b2a4114-95d8-4e6a-b91c-ae9e82df4fae/1280.jpeg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233148414,
#   'title': '習慣躺枕頭睡覺',
#   'excerpt': '人類，枕頭的這一角是我的懂嗎？？？？？？？？整個睡到沒形象...，就是要佔一角，有時候也可以接受枕著人類睡覺，最近剛帶廠長去結紮，結紮前幾天一直跟他說要有心理準備切蛋蛋了，本以為結紮後他會很不爽，結果',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T05:50:41.877Z',
#   'updatedAt': '2020-02-27T06:22:43.649Z',
#   'commentCount': 7,
#   'likeCount': 27,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['貓', '寵物', '米克斯', '領養代替購買'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '國立臺灣大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '4ff5dc5f-e2f4-4358-bd2f-17c5bc5170d7',
#     'url': 'https://i.imgur.com/O4EyM0il.jpg',
#     'normalizedUrl': 'https://i.imgur.com/O4EyM0il.jpg',
#     'thumbnail': 'https://i.imgur.com/O4EyM0il.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'},
#    {'id': '4ff5dc5f-e2f4-4358-bd2f-17c5bc5170d7',
#     'url': 'https://i.imgur.com/O4EyM0i.jpg',
#     'normalizedUrl': 'https://imgur.com/O4EyM0i',
#     'thumbnail': 'https://i.imgur.com/O4EyM0il.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'},
#    {'id': 'ecc68e7a-fb72-4d81-b946-db56f0289544',
#     'url': 'https://i.imgur.com/P6cgoxU.jpg',
#     'normalizedUrl': 'https://imgur.com/P6cgoxU',
#     'thumbnail': 'https://i.imgur.com/P6cgoxUl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'},
#    {'id': '3dcf1856-3da7-4c18-9605-1b2e233d4c95',
#     'url': 'https://i.imgur.com/TqW5LCN.jpg',
#     'normalizedUrl': 'https://imgur.com/TqW5LCN',
#     'thumbnail': 'https://i.imgur.com/TqW5LCNl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'},
#    {'id': '2d1df748-940e-434c-87fa-5a37273e5ed0',
#     'url': 'https://i.imgur.com/2sua9FX.jpg',
#     'normalizedUrl': 'https://imgur.com/2sua9FX',
#     'thumbnail': 'https://i.imgur.com/2sua9FXl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'},
#    {'id': '4c46f845-1b27-4b95-8f36-1160f340c954',
#     'url': 'https://i.imgur.com/bI4seRz.jpg',
#     'normalizedUrl': 'https://imgur.com/bI4seRz',
#     'thumbnail': 'https://i.imgur.com/bI4seRzl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T05:50:41.877Z',
#     'updatedAt': '2020-02-27T06:22:43.649Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 27}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/O4EyM0i.jpg'},
#    {'url': 'https://i.imgur.com/P6cgoxU.jpg'},
#    {'url': 'https://i.imgur.com/TqW5LCN.jpg'},
#    {'url': 'https://i.imgur.com/2sua9FX.jpg'},
#    {'url': 'https://i.imgur.com/bI4seRz.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233154352,
#   'title': '曬照🐿️',
#   'excerpt': '洗澡的阿鼠，包起來以免感冒，放空的，剪指甲，吃花花，蝙蝠🦇（真的不知道它怎麼上去的🤣），吃東西超喜歡倒掛金鉤🤷\u200d️，累到趴的兩隻️，帶它們出去玩變成無尾熊（超害怕完全不敢動），兩隻超乖超黏人 出',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-28T03:46:37.460Z',
#   'updatedAt': '2020-02-28T03:47:32.637Z',
#   'commentCount': 0,
#   'likeCount': 24,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物', '鼠', '松鼠', '曬照'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '國立高雄餐旅大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'e3bffe9b-c399-4b3a-9795-a11032d568a0',
#     'url': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 360,
#     'height': 640},
#    {'id': 'e3bffe9b-c399-4b3a-9795-a11032d568a0',
#     'url': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 1125,
#     'height': 2001},
#    {'id': 'c274293d-3e87-4fb0-b8b8-95656bdfc725',
#     'url': 'https://megapx-assets.dcard.tw/images/f04e4d50-6b64-49b6-a598-e9c38e76034d/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/f04e4d50-6b64-49b6-a598-e9c38e76034d',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/f04e4d50-6b64-49b6-a598-e9c38e76034d/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 1125,
#     'height': 2001},
#    {'id': 'b81488a4-ef38-4c58-b47b-d3c1eda90515',
#     'url': 'https://megapx-assets.dcard.tw/images/f90e978b-1e64-440e-9aeb-b66beecc99db/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/f90e978b-1e64-440e-9aeb-b66beecc99db',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/f90e978b-1e64-440e-9aeb-b66beecc99db/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 2000,
#     'height': 1500},
#    {'id': '5d7aa3bf-64de-4c85-a114-1f3c274fa405',
#     'url': 'https://megapx-assets.dcard.tw/images/38dade35-c4b5-44a1-9ad7-195dbcebd91f/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/38dade35-c4b5-44a1-9ad7-195dbcebd91f',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/38dade35-c4b5-44a1-9ad7-195dbcebd91f/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 750,
#     'height': 1500},
#    {'id': '2295f7e2-5555-4328-94e8-8474e96c1bc2',
#     'url': 'https://megapx-assets.dcard.tw/images/d0d2baf4-e456-4b33-bc8d-9ef97453d047/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/
640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T03:46:37.460Z',
#     'updatedAt': '2020-02-28T03:47:32.637Z',
#     'width': 2000,
#     'height': 1500}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 24}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/5fc5a1a3-1c07-449e-9f0e-707fa1942e45/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/f04e4d50-6b64-49b6-a598-e9c38e76034d/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/f90e978b-1e64-440e-9aeb-b66beecc99db/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/38dade35-c4b5-44a1-9ad7-195dbcebd91f/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/d0d2baf4-e456-4b33-bc8d-9ef97453d047/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/c0e5517b-5de0-4d06-ab8b-f2a501c87b83/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/ee196063-da25-4a90-bfc4-0ebdf9c45c53/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/adc1b243-5812-40c9-a384-ebb2183dc6af/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/6fb767f6-12e2-460d-8997-da96ff5f940f/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/7fb4f10c-18bc-4db4-a230-d6d306b91538/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/2de67672-1ec3-4f37-a6ca-4ee58515fa72/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/f9db29ea-c292-411f-8a29-e9380b194345/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/283e2424-b28e-4d28-94c0-4685d345e109/1280.jpeg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233153760,
#   'title': '文長 我擁有全世界最棒的貓咪',
#   'excerpt': '最愛生氣，非常傲嬌，不喜歡被抱，不喜歡親親，但是，你喜歡整個頭塞進來我們的手裡撒嬌，喜歡靠著爸爸的手陪他打電動，喜歡窩在我的腳上陪我打報告，喜歡窩在我們身邊陪我們睡覺，（醒著的時候你都不理我們），你跟',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T23:47:16.852Z',
#   'updatedAt': '2020-02-27T23:48:09.446Z',
#   'commentCount': 5,
#   'likeCount': 24,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['全世界', '最棒', '貓咪', '我的寶貝', '文長'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '崑山科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'c0c07093-7deb-4c0e-a7cb-869d0ea430bf',
#     'url': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T23:47:16.852Z',
#     'updatedAt': '2020-02-27T23:48:09.446Z',
#     'width': 480,
#     'height': 640},
#    {'id': 'c0c07093-7deb-4c0e-a7cb-869d0ea430bf',
#     'url': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/344d0316-775b-4051-9504-cb82483ee418',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T23:47:16.852Z',
#     'updatedAt': '2020-02-27T23:48:09.446Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '397160fe-7ee7-4a84-8cda-742cdffff47c',
#     'url': 'https://megapx-assets.dcard.tw/images/7a872b19-17ab-47a4-b0de-16af8f592747/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/7a872b19-17ab-47a4-b0de-16af8f592747',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/7a872b19-17ab-47a4-b0de-16af8f592747/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T23:47:16.852Z',
#     'updatedAt': '2020-02-27T23:48:09.446Z',
#     'width': 1500,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 20},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 4}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/344d0316-775b-4051-9504-cb82483ee418/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/7a872b19-17ab-47a4-b0de-16af8f592747/1280.jpeg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233153611,
#   'title': '來曬一下家裡的黑狗🐶',
#   'excerpt': '大家好第一次在寵物版發文（˶‾᷄⁻̫‾᷅˵），來讓大家看一下我家好動得不得了的小黑狗，先放一下牠帥帥的照片，⋯⋯你誰啊（*ﾟﾛﾟ），看到玩具很興奮的樣子，裝可愛，先放到這裡啦！謝謝看到這裡的各位٩（ˊ',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T21:10:15.772Z',
#   'updatedAt': '2020-02-27T21:10:15.772Z',
#   'commentCount': 1,
#   'likeCount': 20,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['狗', '寵物', '可愛', '黑狗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': 'Rennaちゃん',
#   'department': 'renna_2160',
#   'replyTitle': None,
#   'mediaMeta': [{'id': 'fb5412f2-3207-42c1-af21-f456d1bed9d6',
#     'url': 'https://megapx-assets.dcard.tw/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': [],
#     'createdAt': '2020-02-27T21:10:15.772Z',
#     'updatedAt': '2020-02-27T21:10:15.772Z',
#     'width': 480,
#     'height': 640},
#    {'id': 'fb5412f2-3207-42c1-af21-f456d1bed9d6',
#     'url': 'https://megapx-assets.dcard.tw/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/37756146-e3a7-4ec6-91b0-3f44e81b5bbc/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-27T21:10:15.772Z',
#     'updatedAt': '2020-02-27T21:10:15.772Z',
#     'width': 1500,
#     'height': 2000},
#    {'id': '9b3b3143-e1a6-4780-82d9-21756385a2d2',
#     'url': 'https://megapx-assets.dcard.tw/images/a2d81cfe-1038-43d0-b791-5cf8474d4bb4/1280.jpeg',
# ...
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 1600,
#     'height': 2000},
#    {'id': '4ab16584-02f5-409e-9597-841b077787b1',
#     'url': 'https://megapx-assets.dcard.tw/images/441166b8-3426-4a87-ba14-07d314336290/full.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/441166b8-3426-4a87-ba14-07d314336290',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/441166b8-3426-4a87-ba14-07d314336290/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 862,
#     'height': 862},
#    {'id': '8155ba57-42ab-4cd8-a204-a18113081583',
#     'url': 'https://megapx-assets.dcard.tw/images/652b069a-8812-4799-974c-8f013a001952/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/652b069a-8812-4799-974c-8f013a001952',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/652b069a-8812-4799-974c-8f013a001952/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 1501,
#     'height': 2000},
#    {'id': '49f88a30-4294-4587-ad29-1f724e514f60',
#     'url': 'https://megapx-assets.dcard.tw/images/e4f0edf9-944b-486e-814c-47afe00419d2/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/e4f0edf9-944b-486e-814c-47afe00419d2',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/e4f0edf9-944b-486e-814c-47afe00419d2/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 2000,
#     'height': 2000},
#    {'id': 'b8c9918b-fe9f-43e0-91a3-22d4cd1bf5c5',
#     'url': 'https://megapx-assets.dcard.tw/images/394ae436-82fa-4d8b-9c1d-d918d3178bcd/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/394ae436-82fa-4d8b-9c1d-d918d3178bcd',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/394ae436-82fa-4d8b-9c1d-d918d3178bcd/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 2000,
#     'height': 1327},
#    {'id': '2bbc6454-1920-41ab-9192-5ae1974709bb',
#     'url': 'https://megapx-assets.dcard.tw/images/3e4e824d-ab65-4443-b783-181f0fa2e3d7/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/3e4e824d-ab65-4443-b783-181f0fa2e3d7',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/3e4e824d-ab65-4443-b783-181f0fa2e3d7/640.jpeg',
#     'type': 'image/megapx',
#     'tags': [],
#     'createdAt': '2020-02-28T04:37:56.515Z',
#     'updatedAt': '2020-02-28T04:37:56.515Z',
#     'width': 2000,
#     'height': 2000}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 7}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/ad1911b2-a6c8-45c3-bbc9-1cb78e14d61e/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/c68fef76-272a-4dea-ad13-1a1d3a1faa89/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/1abf2d07-cd6c-45f3-ac6a-1bc0dc7d1c3e/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/229e4508-281c-445e-9ab3-8229c7830c49/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/3ffaeb51-e84e-46bb-b942-5c2acbec0d7d/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/b31d2be9-daa2-4bd8-b2e7-bead20374c7b/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/9d15d0eb-f9aa-45a0-b666-094a4f91f415/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/3ee0a54d-d87a-44e4-8fc7-20d750284ba2/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/441166b8-3426-4a87-ba14-07d314336290/full.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/652b069a-8812-4799-974c-8f013a001952/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/e4f0edf9-944b-486e-814c-47afe00419d2/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/394ae436-82fa-4d8b-9c1d-d918d3178bcd/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/3e4e824d-ab65-4443-b783-181f0fa2e3d7/1280.jpeg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233151405,
#   'title': '[抒發文]小狗狗去天堂了',
#   'excerpt': '家中14歲的貴賓狗終於可以放下痛苦 去天堂當快樂的小天使了 我們家最早曾經養過一隻博美，但養了幾年有一天跑出家門就沒回來了 後來聽家人說有看到被別人撿走 好像過的還不錯的樣子，過了十多年家裡都沒再養寵',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T14:08:40.800Z',
#   'updatedAt': '2020-02-28T00:00:18.614Z',
#   'commentCount': 3,
#   'likeCount': 7,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '嘉南藥理大學',
#   'department': '藥學系',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 6},
#    {'id': '514c2569-fd53-4d9d-a415-bf0f88e7329f', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233149191,
#   'title': '從小養到大的主子真的信任我嗎',
#   'excerpt': '以下是主子愛你的表現，你們中了幾個呢？#1 你回到家，會熱情翻肚迎接你，X  坐在樓梯旁看我，＃2 喜歡圍繞在你身邊，蹭蹭你，X完全不會，＃3 喜歡給你抱抱，會主動討摸，XO會主動討摸但死都不給我抱，',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T08:13:49.089Z',
#   'updatedAt': '2020-02-27T08:13:49.089Z',
#   'commentCount': 6,
#   'likeCount': 7,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['主子', '貓', '寵物', '貓咪'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '家有四口喵',
#   'department': 'eve.8.0.4',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 7}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233148275,
#   'title': '學妹揪我一起看貓',
#   'excerpt': '安安，大學快開學了，小大一的學妹跟我同一天回學校，學妹在捷運遇到我，然後跟學妹聊起貓貓的事，學妹就說「我的貓會飛喔！」一直叫我去她宿舍看貓，但我就不信貓會飛啊！，學妹一直很堅持叫我去看會飛的貓，我只好',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T05:18:10.961Z',
#   'updatedAt': '2020-02-27T05:53:31.688Z',
#   'commentCount': 4,
#   'likeCount': 7,
#   'withNickname': False,
#   'tags': ['HIDE_THUMBNAIL'],
#   'topics': ['貓', '寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'M',
#   'school': '國立金門大學',
#   'replyTitle': None,
#   'mediaMeta': [],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 2}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': False,
#   'withVideos': False,
#   'media': [],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233147108,
#   'title': '新手開缸小紀錄｜準備&第一天',
#   'excerpt': '文字多，我想養養的是蝦子，紀錄過程，紀念一下，儘供參考，購入產品資訊在後方，某天滑YouTube，奇妙演算法帶我看到了開缸佈置。接著幾週後搬到新家，看著空空的電視櫃，心中突然有了一個想法。‼️我 也 ',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-26T22:43:32.501Z',
#   'updatedAt': '2020-02-26T22:47:42.740Z',
#   'commentCount': 7,
#   'likeCount': 7,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['魚缸', '蝦缸', '水草', '水草造景', '水族'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '呢',
#   'department': 'tina77527',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '9a961e1d-f642-438e-a806-6ab27b57f04c',
#     'url': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/640.jpeg',
#     'normalizedUrl': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/640.jpeg',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/640.jpeg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:43:32.501Z',
#     'updatedAt': '2020-02-26T22:47:42.740Z',
#     'width': 640,
#     'height': 420},
#    {'id': '9a961e1d-f642-438e-a806-6ab27b57f04c',
#     'url': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/578e316b-1512-4f04-ad92-3de1b24e6f2c',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:43:32.501Z',
#     'updatedAt': '2020-02-26T22:47:42.740Z',
#     'width': 2000,
#     'height': 1312},
#    {'id': '575a19a9-a62a-46a3-a1f5-d96abcdffdff',
#     'url': 'https://megapx-assets.dcard.tw/images/27b4a118-c37f-43c3-ada7-64d06ba87422/1280.jpeg',
#     'normalizedUrl': 'https://megapx.dcard.tw/v1/images/27b4a118-c37f-43c3-ada7-64d06ba87422',
#     'thumbnail': 'https://megapx-assets.dcard.tw/images/27b4a118-c37f-43c3-ada7-64d06ba87422/640.jpeg',
#     'type': 'image/megapx',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-26T22:43:32.501Z',
#     'updatedAt': '2020-02-26T22:47:42.740Z',
#     'width': 2000,
#     'height': 1500}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 7}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://megapx-assets.dcard.tw/images/578e316b-1512-4f04-ad92-3de1b24e6f2c/1280.jpeg'},
#    {'url': 'https://megapx-assets.dcard.tw/images/27b4a118-c37f-43c3-ada7-64d06ba87422/1280.jpeg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233147441,
#   'title': '回不去的喵喵',
#   'excerpt': '最近看到朋友家喵喵剛撿到時的照片，各種覺得不可思議，到底為什麼可以跟現在差這麼多，這張是剛遇到她的時候，不請自來跑來騙飯的流浪喵，當時寒流 房東又不準養寵物，所以朋友給他一些衣物當被子用，後來還是看不',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-27T01:49:34.657Z',
#   'updatedAt': '2020-02-27T01:49:34.657Z',
#   'commentCount': 1,
#   'likeCount': 6,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['喵喵', '貓', '貓咪', '寵物'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '嶺東科技大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '68c6db5b-7236-44f6-a66c-dbe8a175fb40',
#     'url': 'https://i.imgur.com/CRny63el.jpg',
#     'normalizedUrl': 'https://i.imgur.com/CRny63el.jpg',
#     'thumbnail': 'https://i.imgur.com/CRny63el.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:49:34.657Z',
#     'updatedAt': '2020-02-27T01:49:34.657Z'},
#    {'id': '68c6db5b-7236-44f6-a66c-dbe8a175fb40',
#     'url': 'https://i.imgur.com/CRny63e.jpg',
#     'normalizedUrl': 'https://imgur.com/CRny63e',
#     'thumbnail': 'https://i.imgur.com/CRny63el.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:49:34.657Z',
#     'updatedAt': '2020-02-27T01:49:34.657Z'},
#    {'id': '000ecd1a-ba5c-4248-910b-7eee21b9882b',
#     'url': 'https://i.imgur.com/8rmlI9m.jpg',
#     'normalizedUrl': 'https://imgur.com/8rmlI9m',
#     'thumbnail': 'https://i.imgur.com/8rmlI9ml.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:49:34.657Z',
#     'updatedAt': '2020-02-27T01:49:34.657Z'},
#    {'id': '3febf03e-a0cb-46be-b92b-9fc75896f52d',
#     'url': 'https://i.imgur.com/HLqSL9X.jpg',
#     'normalizedUrl': 'https://imgur.com/HLqSL9X',
#     'thumbnail': 'https://i.imgur.com/HLqSL9Xl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-27T01:49:34.657Z',
#     'updatedAt': '2020-02-27T01:49:34.657Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 6}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/CRny63e.jpg'},
#    {'url': 'https://i.imgur.com/8rmlI9m.jpg'},
#    {'url': 'https://i.imgur.com/HLqSL9X.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233155442,
#   'title': '同學我要妮的貓貓！！！',
#   'excerpt': '太可愛了，可以再來幾張照片嗎！！！！，我想吸貓',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-28T07:26:54.480Z',
#   'updatedAt': '2020-02-28T07:26:54.480Z',
#   'commentCount': 1,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['同學', '貓貓'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '臺北市立大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '618d9485-5142-4659-a2d0-279427163f78',
#     'url': 'https://i.imgur.com/1G3Mmfsl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/1G3Mmfsl.jpg',
#     'thumbnail': 'https://i.imgur.com/1G3Mmfsl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T07:26:54.480Z',
#     'updatedAt': '2020-02-28T07:26:54.480Z'},
#    {'id': '618d9485-5142-4659-a2d0-279427163f78',
#     'url': 'https://i.imgur.com/1G3Mmfs.png',
#     'normalizedUrl': 'https://imgur.com/1G3Mmfs',
#     'thumbnail': 'https://i.imgur.com/1G3Mmfsl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T07:26:54.480Z',
#     'updatedAt': '2020-02-28T07:26:54.480Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 5}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/1G3Mmfs.png'}],
#   'reportReasonText': '',
#   'postAvatar': ''},
#  {'id': 233154180,
#   'title': '尋狗 新莊夜市走丟的',
#   'excerpt': '黑色米克斯母犬，在新莊夜市附近走丟的，再麻煩新莊的朋友有看到的話，幫忙注意一下，謝謝謝謝',
#   'anonymousSchool': False,
#   'anonymousDepartment': True,
#   'pinned': False,
#   'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#   'replyId': None,
#   'createdAt': '2020-02-28T02:57:24.261Z',
#   'updatedAt': '2020-02-28T02:57:24.261Z',
#   'commentCount': 0,
#   'likeCount': 5,
#   'withNickname': False,
#   'tags': [],
#   'topics': ['尋狗', '新莊', '寵物', '米克斯', '狗'],
#   'meta': {'layout': 'classic'},
#   'forumName': '寵物',
#   'forumAlias': 'pet',
#   'gender': 'F',
#   'school': '輔仁大學',
#   'replyTitle': None,
#   'mediaMeta': [{'id': '0f4caefc-a51c-483c-a091-12dd43bd73d2',
#     'url': 'https://i.imgur.com/748Qr7hl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/748Qr7hl.jpg',
#     'thumbnail': 'https://i.imgur.com/748Qr7hl.jpg',
#     'type': 'image/thumbnail',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T02:57:24.261Z',
#     'updatedAt': '2020-02-28T02:57:24.261Z'},
#    {'id': '0f4caefc-a51c-483c-a091-12dd43bd73d2',
#     'url': 'https://i.imgur.com/748Qr7h.jpg',
#     'normalizedUrl': 'https://imgur.com/748Qr7h',
#     'thumbnail': 'https://i.imgur.com/748Qr7hl.jpg',
#     'type': 'image/imgur',
#     'tags': ['ANNOTATED'],
#     'createdAt': '2020-02-28T02:57:24.261Z',
#     'updatedAt': '2020-02-28T02:57:24.261Z'}],
#   'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 4},
#    {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 1}],
#   'hidden': False,
#   'customStyle': None,
#   'isSuspiciousAccount': False,
#   'layout': 'classic',
#   'withImages': True,
#   'withVideos': False,
#   'media': [{'url': 'https://i.imgur.com/748Qr7h.jpg'}],
#   'reportReasonText': '',
#   'postAvatar': ''}]

# %%
# 一次會回傳幾筆資料
len(data)
# Out:
# 30

# %%
# 哪些欄位
data[0].keys()
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
data[0]
# Out:
# {'id': 233147249,
#  'title': '有人有看過這麼有喜感的貓嗎',
#  'excerpt': '我家的貓天生帶有喜感，有些照片都可以做成貼圖來賣了，像極了清末在鴉片館的癮君子，又像是坦腹東床的王羲之 再躺也沒有人來相親啦，這三張拉近一看，你是在公三小 我的罐罐你拿去吃掉了？笑死人 聽你在歐北共，',
#  'anonymousSchool': False,
#  'anonymousDepartment': True,
#  'pinned': False,
#  'forumId': '7ee21581-1307-4ba9-b9dc-82028bdcca49',
#  'replyId': None,
#  'createdAt': '2020-02-27T00:41:45.740Z',
#  'updatedAt': '2020-02-27T02:12:02.293Z',
#  'commentCount': 89,
#  'likeCount': 1996,
#  'withNickname': False,
#  'tags': [],
#  'topics': ['貓', '米克斯', '貓咪'],
#  'meta': {'layout': 'classic'},
#  'forumName': '寵物',
#  'forumAlias': 'pet',
#  'gender': 'M',
#  'school': '國立政治大學',
#  'replyTitle': None,
#  'mediaMeta': [{'id': '6be5d281-2419-4f71-aa52-2f7710ca8392',
#    'url': 'https://i.imgur.com/xeJu68Il.jpg',
#    'normalizedUrl': 'https://i.imgur.com/xeJu68Il.jpg',
#    'thumbnail': 'https://i.imgur.com/xeJu68Il.jpg',
#    'type': 'image/thumbnail',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '6be5d281-2419-4f71-aa52-2f7710ca8392',
#    'url': 'https://i.imgur.com/xeJu68I.jpg',
#    'normalizedUrl': 'https://imgur.com/xeJu68I',
#    'thumbnail': 'https://i.imgur.com/xeJu68Il.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '3a84f595-94f9-41ba-8f71-a7e2421bf1a5',
#    'url': 'https://i.imgur.com/9wU5tWX.jpg',
#    'normalizedUrl': 'https://imgur.com/9wU5tWX',
#    'thumbnail': 'https://i.imgur.com/9wU5tWXl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': 'cb349ee1-36ae-493d-81ec-908fd648c570',
#    'url': 'https://i.imgur.com/8zf68zP.jpg',
#    'normalizedUrl': 'https://imgur.com/8zf68zP',
#    'thumbnail': 'https://i.imgur.com/8zf68zPl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '9e44d6f7-04d7-41c5-9e8f-7451c436f14e',
#    'url': 'https://i.imgur.com/D0KSJGO.jpg',
#    'normalizedUrl': 'https://imgur.com/D0KSJGO',
#    'thumbnail': 'https://i.imgur.com/D0KSJGOl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '9f9d49a4-f2be-4085-ac7a-c0ec6efa480c',
#    'url': 'https://i.imgur.com/MgOqlM5.jpg',
#    'normalizedUrl': 'https://imgur.com/MgOqlM5',
#    'thumbnail': 'https://i.imgur.com/MgOqlM5l.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '5cd94ceb-5214-44bf-8e1a-5950c55ae7c8',
#    'url': 'https://i.imgur.com/kd73x0v.jpg',
#    'normalizedUrl': 'https://imgur.com/kd73x0v',
#    'thumbnail': 'https://i.imgur.com/kd73x0vl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': '319e31d0-8369-44fd-8dcf-c14c04a25fe1',
#    'url': 'https://i.imgur.com/RM0fag4.jpg',
#    'normalizedUrl': 'https://imgur.com/RM0fag4',
#    'thumbnail': 'https://i.imgur.com/RM0fag4l.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'},
#   {'id': 'a396f71c-4de9-4762-83c9-cfb576147bbd',
#    'url': 'https://i.imgur.com/Jj3IL0R.jpg',
#    'normalizedUrl': 'https://imgur.com/Jj3IL0R',
#    'thumbnail': 'https://i.imgur.com/Jj3IL0Rl.jpg',
#    'type': 'image/imgur',
#    'tags': ['ANNOTATED'],
#    'createdAt': '2020-02-27T00:41:45.740Z',
#    'updatedAt': '2020-02-27T02:12:02.293Z'}],
#  'reactions': [{'id': '286f599c-f86a-4932-82f0-f5a06f1eca03', 'count': 1872},
#   {'id': 'e8e6bc5d-41b0-4129-b134-97507523d7ff', 'count': 124}],
#  'hidden': False,
#  'customStyle': None,
#  'isSuspiciousAccount': False,
#  'layout': 'classic',
#  'withImages': True,
#  'withVideos': False,
#  'media': [{'url': 'https://i.imgur.com/xeJu68I.jpg'},
#   {'url': 'https://i.imgur.com/9wU5tWX.jpg'},
#   {'url': 'https://i.imgur.com/8zf68zP.jpg'},
#   {'url': 'https://i.imgur.com/D0KSJGO.jpg'},
#   {'url': 'https://i.imgur.com/MgOqlM5.jpg'},
#   {'url': 'https://i.imgur.com/kd73x0v.jpg'},
#   {'url': 'https://i.imgur.com/RM0fag4.jpg'},
#   {'url': 'https://i.imgur.com/Jj3IL0R.jpg'}],
#  'reportReasonText': '',
#  'postAvatar': ''}

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
popular_mean_commentCount = 0
popular_mean_likeCount = 0
popular_total_commentCount = 0
popular_total_likeCount = 0

unpopular_mean_commentCount = 0
unpopular_mean_likeCount = 0
unpopular_total_commentCount = 0
unpopular_total_likeCount = 0

for i in range(len(data)):
    popular_total_commentCount += data[i]['commentCount']
    popular_total_likeCount += data[i]['likeCount']
    
    print('標題：', data[i]['title'])
    print('貼文時間：', data[i]['createdAt'])
    print('留言人數：', data[i]['commentCount'])
    print('按讚人數：', data[i]['likeCount'])
    print('topics：', data[i]['topics'])
    print('meta：', data[i]['meta'])
    print('=====\n')

popular_mean_commentCount = popular_total_commentCount / len(data)
popular_mean_likeCount = popular_total_likeCount / len(data)

print('熱門文章平均留言人數：', popular_mean_commentCount)
print('熱門文章平均按讚人數：', popular_mean_likeCount)
# Out:
# 標題： 感覺是走失的狗狗🐕（？）
# 貼文時間： 2020-02-28T10:27:25.209Z
# 留言人數： 0
# 按讚人數： 1
# topics： ['狗狗', '走失']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 看過醫生了
# 貼文時間： 2020-02-28T10:22:02.363Z
# 留言人數： 0
# 按讚人數： 0
# topics： ['貓']
# meta： {'layout': 'classic'}
# =====
#
# 標題： Costco狗飼料
# 貼文時間： 2020-02-28T09:25:53.455Z
# 留言人數： 2
# 按讚人數： 0
# topics： ['狗', '飼料', '寵物']
# meta： {'layout': 'classic'}
# =====
#
# 標題： #圖 酒醉大鼠
# 貼文時間： 2020-02-28T08:49:27.019Z
# 留言人數： 0
# 按讚人數： 3
# topics： ['鼠', '寵物', '可愛', '倉鼠', '黃金鼠']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 懇請大家協尋狗小孩
# 貼文時間： 2020-02-28T08:09:39.155Z
# 留言人數： 0
# 按讚人數： 5
# topics： ['狗', '寵物', '米克斯', '走失', '協尋']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 虎視眈眈
# 貼文時間： 2020-02-28T08:06:52.057Z
# 留言人數： 2
# 按讚人數： 3
# topics： ['想吃', '肚子餓', '看你飛去哪', '嘰嘰喳喳']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 你肯定有吸！
# 貼文時間： 2020-02-28T07:40:49.986Z
# 留言人數： 0
# 按讚人數： 3
# topics： ['貓', '嗨幾點', '嗨翻天']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 同學我要妮的貓貓！！！
# 貼文時間： 2020-02-28T07:26:54.480Z
# 留言人數： 1
# 按讚人數： 6
# topics： ['同學', '貓貓']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 貓一出門就大叫
# 貼文時間： 2020-02-28T07:19:23.699Z
# 留言人數： 0
# 按讚人數： 3
# topics： ['貓']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 被野貓咬要去打狂犬疫苗嗎
# 貼文時間： 2020-02-28T07:00:46.555Z
# 留言人數： 2
# 按讚人數： 1
# topics： ['狂犬病']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 所以說到底是什麼生物呢
# 貼文時間： 2020-02-28T06:28:07.294Z
# 留言人數： 0
# 按讚人數： 14
# topics： ['貓', '寵物']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 求這篇限時的貓咪
# 貼文時間： 2020-02-28T06:23:06.364Z
# 留言人數： 0
# 按讚人數： 10
# topics： ['限時', '貓', '可愛']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 家中顏值擔當們
# 貼文時間： 2020-02-28T06:13:35.234Z
# 留言人數： 1
# 按讚人數： 2
# topics： ['貓', '米克斯', '貓咪']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 戲精貓-瞳孔放大片篇
# 貼文時間： 2020-02-28T05:13:43.720Z
# 留言人數： 0
# 按讚人數： 4
# topics： ['戲精', '貓', '寵物', '可愛', '領養代替購買']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 柯基犬曬萌照
# 貼文時間： 2020-02-28T04:37:56.515Z
# 留言人數： 0
# 按讚人數： 8
# topics： ['狗', '柯基犬', '寵物']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 三腳黑妞；救援孕狗不是件容易的事
# 貼文時間： 2020-02-28T04:16:05.721Z
# 留言人數： 0
# 按讚人數： 14
# topics： ['救援', '狗', '寵物', '米克斯', '領養代替購買']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 曬照🐿️
# 貼文時間： 2020-02-28T03:46:37.460Z
# 留言人數： 1
# 按讚人數： 26
# topics： ['寵物', '鼠', '松鼠', '曬照']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 尋狗 新莊夜市走丟的
# 貼文時間： 2020-02-28T02:57:24.261Z
# 留言人數： 0
# 按讚人數： 6
# topics： ['尋狗', '新莊', '寵物', '米克斯', '狗']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 貓癬  黴菌
# 貼文時間： 2020-02-28T02:42:39.253Z
# 留言人數： 2
# 按讚人數： 1
# topics： ['貓癬', '黴菌']
# meta： {'layout': 'classic'}
# =====
#
# 標題： #問 法鬥眼睛長腫塊
# 貼文時間： 2020-02-28T00:45:56.977Z
# 留言人數： 1
# 按讚人數： 2
# topics： ['腫塊', '眼睛', '法鬥', '狗', '寵物']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 文長 我擁有全世界最棒的貓咪
# 貼文時間： 2020-02-27T23:47:16.852Z
# 留言人數： 5
# 按讚人數： 25
# topics： ['全世界', '最棒', '貓咪', '我的寶貝', '文長']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 看那顫抖的小眼眶
# 貼文時間： 2020-02-27T22:52:19.976Z
# 留言人數： 2
# 按讚人數： 11
# topics： ['兔', '可愛', '兔兔可愛愛', '奶油寶鼻']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 水族版
# 貼文時間： 2020-02-27T21:57:02.698Z
# 留言人數： 0
# 按讚人數： 2
# topics： ['水族']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 來曬一下家裡的黑狗🐶
# 貼文時間： 2020-02-27T21:10:15.772Z
# 留言人數： 2
# 按讚人數： 22
# topics： ['狗', '寵物', '可愛', '黑狗']
# meta： {'layout': 'classic'}
# =====
#
# 標題： Tina 水族小缸｜章魚哥的院子Day 2
# 貼文時間： 2020-02-27T20:51:28.830Z
# 留言人數： 1
# 按讚人數： 2
# topics： ['章魚哥', '水族', '寵物', '蜜蜂角螺', '蝦子']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 朕想怎麼睡 就怎麼睡(˶‾᷄ ⁻̫ ‾᷅˵)
# 貼文時間： 2020-02-27T19:53:48.404Z
# 留言人數： 0
# 按讚人數： 20
# topics： ['喵喵喵', '米克斯', '長得很像金吉拉', '睡覺', '可愛']
# meta： {'layout': 'classic'}
# =====
#
# 標題： #蓋蘇卡達的屁屁樓
# 貼文時間： 2020-02-27T18:03:14.118Z
# 留言人數： 0
# 按讚人數： 2
# topics： ['蘇卡達']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 賤人！
# 貼文時間： 2020-02-27T17:57:19.700Z
# 留言人數： 3
# 按讚人數： 19
# topics： ['貓']
# meta： {'layout': 'classic'}
# =====
#
# 標題： #協尋紅貴賓#懸賞金$5000#請大家幫忙頂上去！
# 貼文時間： 2020-02-27T17:05:28.180Z
# 留言人數： 3
# 按讚人數： 19
# topics： ['貴賓', '狗', '走失', '協尋', '貴賓狗']
# meta： {'layout': 'classic'}
# =====
#
# 標題： 彈力柴
# 貼文時間： 2020-02-27T14:15:42.605Z
# 留言人數： 0
# 按讚人數： 4
# topics： ['彈力', '狗', '寵物', '柴犬', '好笑']
# meta： {'layout': 'classic'}
# =====
#
# 熱門文章平均留言人數： 0.9333333333333333
# 熱門文章平均按讚人數： 7.933333333333334

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」
unpopular_url = 'https://www.dcard.tw/_api/forums/pet/posts?popular=false'
r = requests.get(unpopular_url)
response = r.text
data = json.loads(response)

for i in range(len(data)):
    unpopular_total_commentCount += data[i]['commentCount']
    unpopular_total_likeCount += data[i]['likeCount']
    
#     print('標題：', data[i]['title'])
#     print('貼文時間：', data[i]['createdAt'])
#     print('留言人數：', data[i]['commentCount'])
#     print('按讚人數：', data[i]['likeCount'])
#     print('topics：', data[i]['topics'])
#     print('meta：', data[i]['meta'])
#     print('=====\n')

unpopular_mean_commentCount = unpopular_total_commentCount / len(data)
unpopular_mean_likeCount = unpopular_total_likeCount / len(data)

print('熱文章總留言數：',popular_total_commentCount )
print('熱文章總讚數：',popular_total_likeCount )
print('非熱文章總留言數：',unpopular_total_commentCount )
print('非熱文章總讚數：',unpopular_total_likeCount )
print('熱門文章平均留言人數：', popular_mean_commentCount)
print('熱門文章平均按讚人數：', popular_mean_likeCount)
print('非熱門文章平均留言人數：', unpopular_mean_commentCount)
print('非熱門文章平均按讚人數：', unpopular_mean_likeCount)
# Out:
# 熱文章總留言數： 28
# 熱文章總讚數： 238
# 非熱文章總留言數： 208
# 非熱文章總讚數： 1702
# 熱門文章平均留言人數： 0.9333333333333333
# 熱門文章平均按讚人數： 7.933333333333334
# 非熱門文章平均留言人數： 6.933333333333334
# 非熱門文章平均按讚人數： 56.733333333333334
